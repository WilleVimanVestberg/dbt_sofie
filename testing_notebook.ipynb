-- %%
USE CATALOG sofie_spark_dbt

-- %%
USE SCHEMA `dbt-schema`

-- %%
select count(*) 
from silver_dedu_ml
where hours_diff >= 0
-- where propertyId IS Not NULL

-- %%
select count(*)
from silver_dedu_all_updates
where TaskPriorityId IS NULL
-- where start_time IS NULL

-- %%
describe silver_dedu_ml

-- %%
select count(distinct(update_row_id))
from silver_dedu_all_updates

-- %%
select count(*) 
from silver_dedu_ML

-- %%
select * from silver_dedu_ML

-- %%
describe silver_dedu_all_updates

-- %%
select count(distinct(ack_OrderNumber)) 
from silver_dedu_ALL_Updates

-- %%
select count(*)
from silver_dedu_only_closed
where days_to_completed = 0

-- %%
select *
from silver_dedu_all_updates

-- %%
-- USE CATALOG hemso_dev
USE SCHEMA bronze

-- %%
select count(*)
from dedu_dedu
where TaskStatusName = 'Kvitterad'
